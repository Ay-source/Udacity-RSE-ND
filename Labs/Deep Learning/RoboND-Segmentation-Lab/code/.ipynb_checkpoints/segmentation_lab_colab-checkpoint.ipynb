# %% [markdown]
# ## Instance Segmentation

# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2026-04-19 23:48:47.213701: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776638927.433696     565 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776638927.480817     565 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776638928.004652     565 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776638928.004683     565 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776638928.004686     565 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776638928.004688     565 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-19 23:48:48.043567: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !rm -rf "./train.zip"
# !rm -rf "./validation.zip"
# !rm -rf "../data"

# !wget "https://s3-us-west-1.amazonaws.com/udacity-robotics/Deep+Learning+Data/Lab/train.zip"
# !wget "https://s3-us-west-1.amazonaws.com/udacity-robotics/Deep+Learning+Data/Lab/validation.zip"

# !mkdir -p "../data/train"
#!mkdir -p "../data/validation"

# !unzip "train.zip" -d "../data"
# !unzip "validation.zip" -d "../data"

# !mv "../data/train_combined/images/" "../data/train/"
# !mv "../data/train_combined/masks/" "../data/train/"
# !rm -rf "../data/train_combined/"

# %% [markdown]
# ## Data Loading

# %%
import glob
from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
train_dir = "../data/train"
valid_dir = "../data/validation"

# %%
train_images_paths, train_masks_paths = shuffle(sorted(glob.glob(train_dir+"/images/*.jpeg")), sorted(glob.glob(train_dir+"/masks/*.png")), random_state=42)
#train_masks_paths = glob.glob(train_dir+"/masks/*.png")

valid_images_paths, valid_masks_paths = shuffle(sorted(glob.glob(valid_dir+"/images/*.jpeg")), sorted(glob.glob(valid_dir+"/masks/*.png")), random_state=42)

assert len(train_images_paths) == len(train_masks_paths)
assert len(valid_images_paths) == len(valid_masks_paths)

# %%
print(f"Total train images is {len(train_images_paths)}")
print(f"Total validation images is {len(valid_images_paths)}")
# Out:
# Total train images is 4131
# Total validation images is 1184

# %%
def load_images(path_list):
    loaded_images = []
    for path in path_list:
        loaded_images.append(cv2.imread(path))
    return np.array(loaded_images)

train_images = load_images(train_images_paths)
train_masks = load_images(train_masks_paths)

# %%
def preprocess(images):
    return images/255.0

# %%
print(f"Train images shape is {train_images.shape}")
print(f"Train masks shape is {train_masks.shape}")
# Out:
# Train images shape is (4131, 256, 256, 3)
# Train masks shape is (4131, 256, 256, 3)

# %%
# Visual representation of data
plt.imshow(train_images[110])

# %%
plt.imshow(train_masks[110])

# %%
train_masks = np.array(train_masks/255.0, dtype=np.int8)#preprocess(train_masks)

# %%
batch_size = 8

train_ds = (
    tf.data.Dataset.from_tensor_slices((train_images, train_masks))
    .shuffle(1000)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
#    .repeat()
)
train_images=0
train_masks=0
# Out:
# I0000 00:00:1776639030.928748     565 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6096 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2026-04-19 23:50:31.031858: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 812187648 exceeds 10% of free system memory.
# 2026-04-19 23:50:33.547862: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 812187648 exceeds 10% of free system memory.
# 2026-04-19 23:50:34.413633: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 812187648 exceeds 10% of free system memory.
# 2026-04-19 23:50:34.994391: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 812187648 exceeds 10% of free system memory.

# %%
valid_images = load_images(valid_images_paths)
valid_masks = load_images(valid_masks_paths)

# %%
print(f"Valid images shape is {valid_images.shape}")
print(f"Valid masks shape is {valid_masks.shape}")
# Out:
# Valid images shape is (1184, 256, 256, 3)
# Valid masks shape is (1184, 256, 256, 3)

# %%
plt.imshow(valid_images[110])

# %%
plt.imshow(valid_masks[110])

# %%
valid_masks = np.array(valid_masks/255.0, dtype=np.int8)#preprocess(valid_masks)

# %%
#train_images = train_images/255.0

# %%
#valid_images = valid_images/255.0

# %%
valid_ds = (
    tf.data.Dataset.from_tensor_slices((valid_images, valid_masks))
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)
valid_images = 0
valid_masks = 0

# %% [markdown]
# ## Defining model

# %%
from keras.models import Model
from keras.layers import Conv2D, Rescaling, Input, UpSampling2D, Concatenate, GlobalAveragePooling2D, UpSampling2D, Reshape, BatchNormalization, Activation
from keras.applications import ResNet50, MobileNetV2
from keras.metrics import BinaryIoU

# %%
input_shape = (256, 256, 3)
trainable = False
def conv_block(inputs, filters, dilation_rate=1, kernel_size=3, stride=1):
    #print("work_conv")
    x = Conv2D(filters, kernel_size, (stride, stride), padding="same", use_bias=False, dilation_rate=(dilation_rate, dilation_rate))(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    #print("End_conv")
    return x

# %%
def base_model(inputs, input_shape=(256, 256, 3), trainable=False):
    base = ResNet50(
        weights="imagenet",
        include_top=False,
        input_shape=input_shape,
        input_tensor=inputs
    )
    base.trainable = trainable
    return base

# %%
def ASPP(input_tensor):
    shape = input_tensor.shape
    #print("Start")
    layer1 = conv_block(input_tensor, 256, 1, 1, 1)
    #print("2")
    layer2 = conv_block(input_tensor, 256, 6, 3, 1)
    #print("3")
    layer3 = conv_block(input_tensor, 256, 12, 3, 1)
    #print("4")
    layer4 = conv_block(input_tensor, 256, 18, 3, 1)
    #print("5")
    layer5 = GlobalAveragePooling2D()(input_tensor)
    layer5 = Reshape((1, 1, layer5.shape[-1]))(layer5)
    layer5 = conv_block(layer5, 256, kernel_size=1)
    layer5 = UpSampling2D(
        size=(shape[1], shape[2]), interpolation="bilinear")(layer5)
    layers_add = Concatenate()([layer1, layer2, layer3, layer4, layer5])
    output = conv_block(layers_add, 256, 1, 1, 1)
    #print("End")
    return output

# %%
def encoder(base):
    layers = [
        "conv2_block3_out",
        "conv4_block6_out"
    ]
    layers = [base.get_layer(name).output for name in layers]
    #model_input = base_model(input_tensor, input_shape=input_shape, trainable)
    #model_ouput = ASPP(model_input)
    #encoder_model = Model(model_input, model_output)
    model = Model(base.input, layers)
    return model

# %%
def decoder(base_input, ASPP_input):
    #print("Start Decoder")
    layer1 = UpSampling2D(size=(4, 4), interpolation="bilinear")(ASPP_input)
    layer_add = Concatenate()([base_input, layer1])
    layer3 = conv_block(layer_add, 256, 1, 3, 1)
    output = UpSampling2D(size=(4, 4), interpolation="bilinear")(layer3)
    #print("End Decoder")
    return output

# %%
def deeplabv3plus(num_classes=3):
    inputs = Input(shape=input_shape)
    rescaled=Rescaling(scale=1./255)(inputs)
    base = base_model(rescaled, input_shape=input_shape, trainable=trainable)
    encoder_output = encoder(base)
    low_level, base_output = encoder_output.output
    aspp_out = ASPP(base_output)
    #print("End encoder")

    low_level = conv_block(low_level, 48, 1, 1, 1)
    decoder_out = decoder(low_level, aspp_out)
    output = Conv2D(num_classes, 1, padding="same", activation="sigmoid")(decoder_out)
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
model = deeplabv3plus()

# %% [markdown]
# ## Training and Testing

# %%
learning_rate = 1e-4
batch_size=8
epochs = 60

# %%
# Dice Loss and cross entropy loss
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    d_loss = (2 * intersection + smooth) / (union + smooth)
    return 1.0 - tf.reduce_mean(d_loss)

cross_entropy_loss = tf.keras.losses.BinaryCrossentropy()


def total_loss(y_true, y_pred):
  return dice_loss(y_true, y_pred) + cross_entropy_loss(y_true, y_pred)

# %%
# meen IoU
def meanIoU():
    mI
    return mIoU

# %%
import tensorflow as tf

class MeanIoUCustom(tf.keras.metrics.Metric):
    def __init__(self, num_classes, ignore_class=None, name="mIoU", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.ignore_class = ignore_class

        self.total_cm = self.add_weight(
            name="total_confusion_matrix",
            shape=(num_classes, num_classes),
            initializer="zeros",
            dtype=tf.float32
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        """
        y_true: (B, H, W)
        y_pred: (B, H, W, C) logits
        """
        y_pred = tf.argmax(y_pred, axis=-1)
        y_true = tf.cast(y_true, tf.int32)
        y_pred = tf.cast(y_pred, tf.int32)

        # Flatten
        y_true = tf.reshape(y_true, [-1])
        y_pred = tf.reshape(y_pred, [-1])

        # Ignore label mask
        if self.ignore_class is not None:
            mask = tf.not_equal(y_true, self.ignore_class)
            y_true = tf.boolean_mask(y_true, mask)
            y_pred = tf.boolean_mask(y_pred, mask)

        cm = tf.math.confusion_matrix(
            y_true,
            y_pred,
            num_classes=self.num_classes,
            dtype=tf.float32
        )

        self.total_cm.assign_add(cm)

    def result(self):
        sum_over_row = tf.reduce_sum(self.total_cm, axis=0)
        sum_over_col = tf.reduce_sum(self.total_cm, axis=1)
        true_positives = tf.linalg.diag_part(self.total_cm)

        denominator = sum_over_row + sum_over_col - true_positives
        iou = true_positives / (denominator + 1e-7)

        return tf.reduce_mean(iou)

    def reset_states(self):
        self.total_cm.assign(tf.zeros_like(self.total_cm))

# %%
miou = MeanIoUCustom(num_classes=3, ignore_class=255)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss=total_loss,
    #metrics=["accuracy"]
    #metrics=[miou]
    metrics = [BinaryIoU(target_class_ids=[0, 1], threshold=0.3)]
)

# %%
#model.fit(
#    train_images, train_masks,
#    batch_size=batch_size,
#    epochs=epochs,
#)
model.fit(
    train_ds,
    validation_data=valid_ds,
    epochs=epochs,
)
# Out:
# Epoch 1/60
# 2026-04-19 23:59:01.815828: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 812187648 exceeds 10% of free system memory.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776639559.020596    1109 service.cc:152] XLA service 0x7b2898013420 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776639559.021502    1109 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 2070 with Max-Q Design, Compute Capability 7.5
# 2026-04-19 23:59:19.587996: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1776639561.588403    1109 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2026-04-19 23:59:24.014865: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.135 = (f32[8,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,64,64,64]{3,2,1,0} %bitcast.10944, f32[64,64,3,3]{3,2,1,0} %bitcast.10951, f32[64]{0} %bitcast.10953), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2_block1_2_conv_1/convolution" source_file="/home/forby/miniconda3/envs/sdc/lib/python3.11/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2026-04-19 23:59:24.824947: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.145 = (f32[8,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,128,32,32]{3,2,1,0} %bitcast.11349, f32[128,128,3,3]{3,2,1,0} %bitcast.11356, f32[128]{0} %bitcast.11358), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv3_block1_2_conv_1/convolution" source_file="/home/forby/miniconda3/envs/sdc/lib/python3.11/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2026-04-19 23:59:25.334751: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.158 = (f32[8,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,256,16,16]{3,2,1,0} %bitcast.11877, f32[256,256,3,3]{3,2,1,0} %bitcast.11884, f32[256]{0} %bitcast.11886), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv4_block1_2_conv_1/convolution" source_file="/home/forby/miniconda3/envs/sdc/lib/python3.11/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2026-04-19 23:59:28.531651: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-04-19 23:59:29.485401: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.97GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-04-19 23:59:30.828633: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.92GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-04-19 23:59:31.836916: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 7.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-04-19 23:59:32.124918: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 7.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-04-19 23:59:34.142245: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.70GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# I0000 00:00:1776639579.131466    1109 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 516/517 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - binary_io_u: 0.7937 - loss: 0.4291
# 2026-04-20 00:01:49.333793: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.145 = (f32[3,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[3,128,32,32]{3,2,1,0} %bitcast.11351, f32[128,128,3,3]{3,2,1,0} %bitcast.11358, f32[128]{0} %bitcast.11360), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv3_block1_2_conv_1/convolution" source_file="/home/forby/miniconda3/envs/sdc/lib/python3.11/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2026-04-20 00:01:49.687225: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.158 = (f32[3,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[3,256,16,16]{3,2,1,0} %bitcast.11879, f32[256,256,3,3]{3,2,1,0} %bitcast.11886, f32[256]{0} %bitcast.11888), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv4_block1_2_conv_1/convolution" source_file="/home/forby/miniconda3/envs/sdc/lib/python3.11/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2026-04-20 00:01:51.135108: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.72GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-04-20 00:01:51.634280: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.78GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-04-20 00:01:52.383344: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.76GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-04-20 00:01:52.786909: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.69GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 203s 319ms/step - binary_io_u: 0.9184 - loss: 0.2316 - val_binary_io_u: 0.9748 - val_loss: 0.0987
# Epoch 2/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9779 - loss: 0.0738 - val_binary_io_u: 0.9460 - val_loss: 0.1757
# Epoch 3/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 285ms/step - binary_io_u: 0.9795 - loss: 0.0546 - val_binary_io_u: 0.9766 - val_loss: 0.0620
# Epoch 4/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 285ms/step - binary_io_u: 0.9810 - loss: 0.0461 - val_binary_io_u: 0.9723 - val_loss: 0.0785
# Epoch 5/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 285ms/step - binary_io_u: 0.9818 - loss: 0.0415 - val_binary_io_u: 0.9749 - val_loss: 0.0742
# Epoch 6/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9826 - loss: 0.0382 - val_binary_io_u: 0.9762 - val_loss: 0.0631
# Epoch 7/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 147s 285ms/step - binary_io_u: 0.9831 - loss: 0.0363 - val_binary_io_u: 0.9799 - val_loss: 0.0465
# Epoch 8/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 147s 285ms/step - binary_io_u: 0.9837 - loss: 0.0343 - val_binary_io_u: 0.9801 - val_loss: 0.0487
# Epoch 9/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9844 - loss: 0.0323 - val_binary_io_u: 0.9783 - val_loss: 0.0600
# Epoch 10/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 285ms/step - binary_io_u: 0.9850 - loss: 0.0307 - val_binary_io_u: 0.9813 - val_loss: 0.0424
# Epoch 11/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 147s 285ms/step - binary_io_u: 0.9852 - loss: 0.0302 - val_binary_io_u: 0.8837 - val_loss: 0.2486
# Epoch 12/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 145s 281ms/step - binary_io_u: 0.9856 - loss: 0.0292 - val_binary_io_u: 0.9795 - val_loss: 0.0568
# Epoch 13/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9860 - loss: 0.0280 - val_binary_io_u: 0.9756 - val_loss: 0.0875
# Epoch 14/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9864 - loss: 0.0272 - val_binary_io_u: 0.9799 - val_loss: 0.0509
# Epoch 15/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9868 - loss: 0.0264 - val_binary_io_u: 0.9615 - val_loss: 0.0779
# Epoch 16/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9872 - loss: 0.0254 - val_binary_io_u: 0.9825 - val_loss: 0.0457
# Epoch 17/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9872 - loss: 0.0253 - val_binary_io_u: 0.9306 - val_loss: 0.1373
# Epoch 18/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9872 - loss: 0.0252 - val_binary_io_u: 0.8575 - val_loss: 0.3195
# Epoch 19/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9875 - loss: 0.0245 - val_binary_io_u: 0.9755 - val_loss: 0.0992
# Epoch 20/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9876 - loss: 0.0242 - val_binary_io_u: 0.9790 - val_loss: 0.0748
# Epoch 21/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9881 - loss: 0.0234 - val_binary_io_u: 0.9725 - val_loss: 0.2691
# Epoch 22/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9881 - loss: 0.0232 - val_binary_io_u: 0.9441 - val_loss: 0.1130
# Epoch 23/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9884 - loss: 0.0226 - val_binary_io_u: 0.9786 - val_loss: 0.0601
# Epoch 24/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9882 - loss: 0.0229 - val_binary_io_u: 0.9770 - val_loss: 0.0537
# Epoch 25/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9887 - loss: 0.0220 - val_binary_io_u: 0.3432 - val_loss: 2.4610
# Epoch 26/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9888 - loss: 0.0217 - val_binary_io_u: 0.9590 - val_loss: 0.0896
# Epoch 27/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9888 - loss: 0.0218 - val_binary_io_u: 0.9844 - val_loss: 0.0400
# Epoch 28/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9891 - loss: 0.0210 - val_binary_io_u: 0.9809 - val_loss: 0.0648
# Epoch 29/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9892 - loss: 0.0208 - val_binary_io_u: 0.9742 - val_loss: 0.1360
# Epoch 30/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9894 - loss: 0.0204 - val_binary_io_u: 0.9337 - val_loss: 0.1326
# Epoch 31/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9888 - loss: 0.0217 - val_binary_io_u: 0.9805 - val_loss: 0.0487
# Epoch 32/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9895 - loss: 0.0201 - val_binary_io_u: 0.9717 - val_loss: 0.0642
# Epoch 33/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9896 - loss: 0.0200 - val_binary_io_u: 0.9846 - val_loss: 0.0395
# Epoch 34/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9893 - loss: 0.0205 - val_binary_io_u: 0.9814 - val_loss: 0.0725
# Epoch 35/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9896 - loss: 0.0200 - val_binary_io_u: 0.9201 - val_loss: 0.1578
# Epoch 36/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9899 - loss: 0.0194 - val_binary_io_u: 0.9770 - val_loss: 0.1120
# Epoch 37/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9901 - loss: 0.0190 - val_binary_io_u: 0.9817 - val_loss: 0.0446
# Epoch 38/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9899 - loss: 0.0194 - val_binary_io_u: 0.9769 - val_loss: 0.0959
# Epoch 39/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9901 - loss: 0.0188 - val_binary_io_u: 0.9786 - val_loss: 0.0945
# Epoch 40/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9901 - loss: 0.0190 - val_binary_io_u: 0.9818 - val_loss: 0.0669
# Epoch 41/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9899 - loss: 0.0193 - val_binary_io_u: 0.9497 - val_loss: 0.1023
# Epoch 42/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9903 - loss: 0.0185 - val_binary_io_u: 0.9838 - val_loss: 0.0553
# Epoch 43/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9904 - loss: 0.0182 - val_binary_io_u: 0.9480 - val_loss: 0.1102
# Epoch 44/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9906 - loss: 0.0179 - val_binary_io_u: 0.9817 - val_loss: 0.0674
# Epoch 45/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9905 - loss: 0.0180 - val_binary_io_u: 0.9790 - val_loss: 0.0974
# Epoch 46/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9905 - loss: 0.0182 - val_binary_io_u: 0.9397 - val_loss: 0.1432
# Epoch 47/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9902 - loss: 0.0188 - val_binary_io_u: 0.9825 - val_loss: 0.0452
# Epoch 48/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 149s 288ms/step - binary_io_u: 0.9906 - loss: 0.0179 - val_binary_io_u: 0.9766 - val_loss: 0.0744
# Epoch 49/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9907 - loss: 0.0176 - val_binary_io_u: 0.6195 - val_loss: 1.0653
# Epoch 50/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u: 0.9906 - loss: 0.0179 - val_binary_io_u: 0.9834 - val_loss: 0.0641
# Epoch 51/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9907 - loss: 0.0176 - val_binary_io_u: 0.9862 - val_loss: 0.0462
# Epoch 52/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 149s 288ms/step - binary_io_u: 0.9910 - loss: 0.0171 - val_binary_io_u: 0.9845 - val_loss: 0.0491
# Epoch 53/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9910 - loss: 0.0172 - val_binary_io_u: 0.9252 - val_loss: 0.1605
# Epoch 54/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9906 - loss: 0.0179 - val_binary_io_u: 0.9837 - val_loss: 0.0550
# Epoch 55/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9911 - loss: 0.0169 - val_binary_io_u: 0.9783 - val_loss: 0.1111
# Epoch 56/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9910 - loss: 0.0171 - val_binary_io_u: 0.9805 - val_loss: 0.0585
# Epoch 57/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9911 - loss: 0.0168 - val_binary_io_u: 0.9798 - val_loss: 0.0873
# Epoch 58/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9909 - loss: 0.0173 - val_binary_io_u: 0.9789 - val_loss: 0.0571
# Epoch 59/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u: 0.9913 - loss: 0.0165 - val_binary_io_u: 0.9837 - val_loss: 0.0646
# Epoch 60/60
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 149s 287ms/step - binary_io_u: 0.9913 - loss: 0.0165 - val_binary_io_u: 0.9813 - val_loss: 0.0504

# %%
model.save("deeplabv3.keras")

# %%
valid_images = load_images(valid_images_paths)

# %%
index = 110 #1, 4, 8, 9, 10, 11, 19, 110, 1110, 1111
test_im = valid_images[index]

# %%
valid_masks = load_images(valid_masks_paths)
plt.imshow(valid_masks[index])

# %%
test_im = tf.reshape(test_im, [1, test_im.shape[0], test_im.shape[-2], test_im.shape[-1]])
test_im.shape
# Out:
# TensorShape([1, 256, 256, 3])

# %%
output = model.predict([test_im])
# Out:
# /home/forby/miniconda3/envs/sdc/lib/python3.11/site-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: input_layer
# Received: inputs=('Tensor(shape=(1, 256, 256, 3))',)
#   warnings.warn(msg)
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b29cb5556c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step

# %%
plt.imshow(test_im[0])

# %%
pred = model.predict(test_im)[0]
mask = (pred >= 0.8).astype("uint8")
mask_only = (mask[..., 0] == 0) & (mask[..., 1] == 0) & (mask[..., -1] == 0)
#print("here")
mask_only = mask_only.astype(np.uint8) * 255
#print(mask_only[0][100:150])
mask[mask_only==255] = [0, 0, 1] 
#print(mask[0][100:150])
# Out:
# WARNING:tensorflow:6 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b29cb5556c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step

# %%
plt.imshow(mask*255)

# %%
valid_masks=0
valid_images=0

# %% [markdown]
# ## Finetuning

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model("deeplabv3.keras",
                  custom_objects={"total_loss": total_loss}
                  )

# %%
def deeplabv3plus(num_classes=3):
    inputs = Input(shape=input_shape)
    rescaled=Rescaling(scale=1./255)(inputs)
    base = base_model(rescaled, input_shape=input_shape, trainable=True)
    encoder_output = encoder(base)
    low_level, base_output = encoder_output.output
    aspp_out = ASPP(base_output)
    #print("End encoder")

    low_level = conv_block(low_level, 48, 1, 1, 1)
    decoder_out = decoder(low_level, aspp_out)
    output = Conv2D(num_classes, 1, padding="same")(decoder_out)
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=total_loss,
    #metrics=["accuracy"]
    #metrics=[miou]
    metrics = [BinaryIoU(target_class_ids=[0, 1], threshold=0.3)]
)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.4,
    patience=5,
    min_lr=1e-9
)

# %%
model.fit(
    train_ds,
    validation_data=valid_ds,
    epochs=50,
    callbacks = [reduce_lr]
)
# Out:
# Epoch 1/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 174s 306ms/step - binary_io_u_2: 0.9916 - loss: 0.0158 - val_binary_io_u_2: 0.9877 - val_loss: 0.0415 - learning_rate: 1.0000e-05
# Epoch 2/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u_2: 0.9918 - loss: 0.0155 - val_binary_io_u_2: 0.9877 - val_loss: 0.0415 - learning_rate: 1.0000e-05
# Epoch 3/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u_2: 0.9918 - loss: 0.0154 - val_binary_io_u_2: 0.9874 - val_loss: 0.0352 - learning_rate: 1.0000e-05
# Epoch 4/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u_2: 0.9918 - loss: 0.0154 - val_binary_io_u_2: 0.9876 - val_loss: 0.0425 - learning_rate: 1.0000e-05
# Epoch 5/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u_2: 0.9918 - loss: 0.0153 - val_binary_io_u_2: 0.9878 - val_loss: 0.0356 - learning_rate: 1.0000e-05
# Epoch 6/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u_2: 0.9918 - loss: 0.0153 - val_binary_io_u_2: 0.9880 - val_loss: 0.0360 - learning_rate: 1.0000e-05
# Epoch 7/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u_2: 0.9919 - loss: 0.0153 - val_binary_io_u_2: 0.9877 - val_loss: 0.0431 - learning_rate: 1.0000e-05
# Epoch 8/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u_2: 0.9919 - loss: 0.0152 - val_binary_io_u_2: 0.9881 - val_loss: 0.0385 - learning_rate: 1.0000e-05
# Epoch 9/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 149s 287ms/step - binary_io_u_2: 0.9919 - loss: 0.0152 - val_binary_io_u_2: 0.9880 - val_loss: 0.0397 - learning_rate: 2.0000e-06
# Epoch 10/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u_2: 0.9919 - loss: 0.0151 - val_binary_io_u_2: 0.9881 - val_loss: 0.0399 - learning_rate: 2.0000e-06
# Epoch 11/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u_2: 0.9919 - loss: 0.0151 - val_binary_io_u_2: 0.9879 - val_loss: 0.0412 - learning_rate: 2.0000e-06
# Epoch 12/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 145s 280ms/step - binary_io_u_2: 0.9919 - loss: 0.0151 - val_binary_io_u_2: 0.9881 - val_loss: 0.0395 - learning_rate: 2.0000e-06
# Epoch 13/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u_2: 0.9919 - loss: 0.0151 - val_binary_io_u_2: 0.9880 - val_loss: 0.0397 - learning_rate: 2.0000e-06
# Epoch 14/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 149s 288ms/step - binary_io_u_2: 0.9919 - loss: 0.0151 - val_binary_io_u_2: 0.9880 - val_loss: 0.0396 - learning_rate: 4.0000e-07
# Epoch 15/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u_2: 0.9919 - loss: 0.0151 - val_binary_io_u_2: 0.9880 - val_loss: 0.0402 - learning_rate: 4.0000e-07
# Epoch 16/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u_2: 0.9919 - loss: 0.0151 - val_binary_io_u_2: 0.9880 - val_loss: 0.0400 - learning_rate: 4.0000e-07
# Epoch 17/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 149s 288ms/step - binary_io_u_2: 0.9919 - loss: 0.0151 - val_binary_io_u_2: 0.9880 - val_loss: 0.0394 - learning_rate: 4.0000e-07
# Epoch 18/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 287ms/step - binary_io_u_2: 0.9919 - loss: 0.0151 - val_binary_io_u_2: 0.9880 - val_loss: 0.0395 - learning_rate: 4.0000e-07
# Epoch 19/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u_2: 0.9920 - loss: 0.0151 - val_binary_io_u_2: 0.9880 - val_loss: 0.0398 - learning_rate: 8.0000e-08
# Epoch 20/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 148s 286ms/step - binary_io_u_2: 0.9920 - loss: 0.0150 - val_binary_io_u_2: 0.9880 - val_loss: 0.0400 - learning_rate: 8.0000e-08
# Epoch 21/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 149s 287ms/step - binary_io_u_2: 0.9920 - loss: 0.0150 - val_binary_io_u_2: 0.9880 - val_loss: 0.0398 - learning_rate: 8.0000e-08
# Epoch 22/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 149s 288ms/step - binary_io_u_2: 0.9920 - loss: 0.0151 - val_binary_io_u_2: 0.9880 - val_loss: 0.0398 - learning_rate: 8.0000e-08
# Epoch 23/50
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 147s 285ms/step - binary_io_u_2: 0.9920 - loss: 0.0151 - val_binary_io_u_2: 0.9880 - val_loss: 0.0396 - learning_rate: 8.0000e-08
# Epoch 24/50
#  72/517 ━━━━━━━━━━━━━━━━━━━━ 1:56 262ms/step - binary_io_u_2: 0.9923 - loss: 0.0145
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 model.fit(
#       2     train_ds,
#       3     validation_data=valid_ds,
#       4     epochs=50,
#       5     callbacks = [reduce_lr]
#       6 )
#
# File ~/miniconda3/envs/sdc/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/sdc/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:377, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375 for begin_step, end_step, iterator in epoch_iterator:
#     376     callbacks.on_train_batch_begin(begin_step)
# --> 377     logs = self.train_function(iterator)
#     378     callbacks.on_train_batch_end(end_step, logs)
#     379     if self.stop_training:
#
# File ~/miniconda3/envs/sdc/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:221, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     217 if isinstance(
#     218     iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219 ):
#     220     opt_outputs = multi_step_on_iterator(iterator)
# --> 221     if not opt_outputs.has_value():
#     222         raise StopIteration
#     223     return opt_outputs.get_value()
#
# File ~/miniconda3/envs/sdc/lib/python3.11/site-packages/tensorflow/python/data/ops/optional_ops.py:176, in _OptionalImpl.has_value(self, name)
#     174 def has_value(self, name=None):
#     175   with ops.colocate_with(self._variant_tensor):
# --> 176     return gen_optional_ops.optional_has_value(
#     177         self._variant_tensor, name=name
#     178     )
#
# File ~/miniconda3/envs/sdc/lib/python3.11/site-packages/tensorflow/python/ops/gen_optional_ops.py:172, in optional_has_value(optional, name)
#     170 if tld.is_eager:
#     171   try:
# --> 172     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     173       _ctx, "OptionalHasValue", name, optional)
#     174     return _result
#     175   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.save("deeplabv3_finetune.keras")
